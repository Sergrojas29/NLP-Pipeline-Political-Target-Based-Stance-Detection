# %%
import pandas as pd

# %%
df = pd.read_csv("DATA/allsides.csv")
df.head(25)
left_sources = df[df["bias"]== "left"]
right_sources = df[df["bias"]== "right"]

# %%
left_sources.sort_values('agree_ratio', ascending=False).head(10)
# Out:
#                          name  bias  total_votes  agree  disagree  \
# 206              Mother Jones  left        17416  15171      2245
# 7                    AlterNet  left        16591  13639      2952
# 62              CNN (Opinion)  left        40486  33168      7318
# 89              Democracy Now  left        16298  13250      3048
# 371            The New Yorker  left        11568   9323      2245
# 247                  PinkNews  left          149    120        29
# 157                   Jacobin  left         1210    974       236
# 414                      Vice  left         4062   3231       831
# 207                     MSNBC  left        26299  20886      5413
# 224  New York Times (Opinion)  left        18114  14256      3858
#
#      agree_ratio     agreeance_text  \
# 206     6.757684  Absolutely Agrees
# 7       4.620257  Absolutely Agrees
# 62      4.532386  Absolutely Agrees
# 89      4.347113  Absolutely Agrees
# 371     4.152784  Absolutely Agrees
# ...

# %% [markdown]
# Link to most agreed sites that are left leaning :
# ['https://www.allsides.com/news-source/mother-jones-bias',
#  'https://www.allsides.com/news-source/alternet-media-bias',
#  'https://www.allsides.com/news-source/cnn-editorial',
#  'https://www.allsides.com/news-source/democracy-now',
#  'https://www.allsides.com/news-source/new-yorker',
#  'https://www.allsides.com/news-source/pinknews-media-bias',
#  'https://www.allsides.com/news-source/jacobin-media-bias',
#  'https://www.allsides.com/news-source/vice-media-bias',
#  'https://www.allsides.com/news-source/msnbc',
#  'https://www.allsides.com/news-source/new-york-times-opinion-media-bias'   ]

# %%
right_sources.sort_values('agree_ratio', ascending=False).head(10)
# Out:
#                        name   bias  total_votes  agree  disagree  agree_ratio  \
# 149                InfoWars  right         6395   5246      1149     4.565709
# 122      Fox News (Opinion)  right        34262  27753      6509     4.263789
# 370      The National Pulse  right          574    461       113     4.079646
# 37           Breitbart News  right        50379  39162     11217     3.491308
# 347          The Federalist  right        11785   9021      2764     3.263748
# 400     The Western Journal  right         2322   1747       575     3.038261
# 227       Newsmax - Opinion  right          670    504       166     3.036145
# 322  The American Spectator  right        16056  11908      4148     2.870781
# 24    Biblical Gender Roles  right          232    172        60     2.866667
# 341          The Daily Wire  right        14290  10511      3779     2.781424
#
#         agreeance_text                                      allsides_page
# ...

# %% [markdown]
# ['https://www.allsides.com/news-source/infowars',
#  'https://www.allsides.com/news-source/fox-news-editorial-media-bias',
#  'https://www.allsides.com/news-source/national-pulse-media-bias',
#  'https://www.allsides.com/news-source/breitbart',
#  'https://www.allsides.com/news-source/federalist',
#  'https://www.allsides.com/news-source/western-journalism',
#  'https://www.allsides.com/news-source/newsmax-opinion-media-bias',
#  'https://www.allsides.com/news-source/american-spectator',
#  'https://www.allsides.com/news-source/biblical-gender-roles-media-bias',
#  'https://www.allsides.com/news-source/daily-wire']

# %%
df.sort_values("total_votes", ascending=False)[:10]
# Out:
#                        name         bias  total_votes  agree  disagree  \
# 401            TheBlaze.com        right       179490  99383     80107
# 61        CNN (Online News)         left        98448  50713     47735
# 121  Fox News (Online News)        right        89187  41644     47543
# 223   New York Times (News)  left-center        67516  28834     38682
# 234       NPR (Online News)       center        61433  31554     29879
# 427         Washington Post  left-center        59917  35626     24291
# 141                HuffPost         left        57607  35386     22221
# 21                 BBC News       center        54202  29177     25025
# 250                Politico  left-center        53411  23285     30126
# 0         ABC News (Online)  left-center        53210  35301     17909
#
#      agree_ratio      agreeance_text  \
# 401     1.240628     Somewhat Agrees
# 61      1.062386     Somewhat Agrees
# 121     0.875923  Somewhat Disagrees
# ...

# %% [markdown]
# Here are some datasets to consider:
#
# Allsides News Dataset (kaggle and huggingface).
# BASIL https://github.com/launchnlp/BASIL
# MBIC (on kaggle)
# https://huggingface.co/datasets/newsmediabias/news-bias-full-data
# https://www.kaggle.com/datasets/timospinde/babe-media-bias-annotations-by-experts
